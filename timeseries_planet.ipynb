# %%
import os
from mpetools import IslandTime, TimeSeriesPreProcessing
import numpy as np
import json
import requests
from requests.auth import HTTPBasicAuth
import matplotlib.pyplot as plt
from osgeo import gdal
import pyproj
from skimage.filters import threshold_multiotsu
from skimage import measure
from xml.dom import minidom
import datetime
import scipy.signal
import scipy.stats
from celluloid import Camera
import shapely
import geopandas as gpd
from skimage import io
from sklearn.cluster import KMeans
from sklearn.utils import shuffle
from statsmodels.tsa.seasonal import STL, seasonal_decompose, MSTL
import pymannkendall as mk

# %%
island = 'Vodamulaa'
country = 'Maldives'
island_info = IslandTime.retrieve_island_info(island, country, verbose=False)
island_info = TimeSeriesPreProcessing.PreProcess(island_info).main()
# Out:
# -------------------------------------------------------------------
# Time series pre-processing
# Island: Vodamulaa, Maldives
# -------------------------------------------------------------------

# %%
ts = island_info['timeseries_preprocessing']['optimal time period']['dict_timeseries']['coastline_position_transect_0_waterline']['monthly']['coastline_position_transect_0_waterline']
ts_o = island_info['timeseries_preprocessing']['optimal time period']['dict_timeseries']['coastline_position_transect_32_waterline']['monthly']['coastline_position_transect_32_waterline']

# %%
model = STL(ts).fit()
model.trend.plot(color='r', label='trend')
ts.plot(color='k', label='coastline position transect 0')

plt.xlabel('time', fontsize=12)
plt.ylabel('coastline position (m)', fontsize=12)
plt.legend()

trend = model.trend
ss = model.seasonal

# %%
peaks, _ = scipy.signal.find_peaks(ss, height=1.)

ss.plot()
for i in peaks:
    plt.axvline(x=ss.index[i], color='g', linestyle='--')

# %%
ss.index[peaks]
# Out:
# DatetimeIndex(['2014-12-31 00:00:00+00:00', '2015-04-30 00:00:00+00:00',
#                '2016-04-30 00:00:00+00:00', '2017-03-31 00:00:00+00:00',
#                '2018-03-31 00:00:00+00:00', '2019-03-31 00:00:00+00:00',
#                '2020-02-29 00:00:00+00:00', '2021-02-28 00:00:00+00:00',
#                '2022-02-28 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', freq=None)

# %%
[ss.index[peaks][i + 1] - ss.index[peaks][i] for i in range(len(ss.index[peaks]) - 1)]
# Out:
# [Timedelta('120 days 00:00:00'),
#  Timedelta('366 days 00:00:00'),
#  Timedelta('335 days 00:00:00'),
#  Timedelta('365 days 00:00:00'),
#  Timedelta('365 days 00:00:00'),
#  Timedelta('335 days 00:00:00'),
#  Timedelta('365 days 00:00:00'),
#  Timedelta('365 days 00:00:00')]

# %%
x = np.linspace(0, 1000, 1000)
period = 365
y = np.sin(2 * np.pi * (x-90) / period)
plt.plot(x, y)

# %%
start_date = ss.index[0]
numeric_dates = np.array([(date - start_date).days for date in ss.index])

# %%
np.diff(numeric_dates[peaks])
# Out:
# array([120, 366, 335, 365, 365, 335, 365, 365])

# %%
plt.plot(numeric_dates, ss)

# %%
# Define the sinusoidal function
def sinusoidal_function(x, A, k, p, phi, offset):
    return A * np.exp(k*x) * np.sin(2 * np.pi / p * x + phi) + offset

# %%
from scipy.optimize import curve_fit

# Generate example data
x_data = numeric_dates
#y_true = 2 * np.sin(2 * np.pi * 1 * x_data + np.pi/2) + 1
#y_data = y_true + 0.5 * np.random.normal(size=len(x_data))  # Add some noise
y_data = ss.values

# Fit the data to the sinusoidal function
initial_guess = [7, 0.001, 365, 90, 0]  # Initial guess for amplitude, frequency, phase, and offset
params, covariance = curve_fit(sinusoidal_function, x_data, y_data, p0=initial_guess)

# Extract the fitted parameters
A_fit, k_fit, f_fit, phi_fit, offset_fit = params

# Generate the fitted curve
y_fit = sinusoidal_function(x_data, A_fit, k_fit, f_fit, phi_fit, offset_fit)

# Plot the original data, true sinusoidal curve, and the fitted curve
plt.plot(x_data, y_data, label='Time Series (seasonal component)')
#plt.plot(x_data, y_true, label='True Sinusoidal Curve', linestyle='--', linewidth=2)
plt.plot(x_data, y_fit, label= '{} exp({}t) sin(2t*pi/{} + {}) + {}'.format(np.round(A_fit, 1), np.round(k_fit, 4), np.round(f_fit, 0), np.round(phi_fit, 0), np.round(offset_fit, 2)), linestyle='-', linewidth=2)
plt.legend()
plt.xlabel('time since start day (days)', fontsize=12)
plt.ylabel('coastline position (seasonal)', fontsize=12)
plt.show()

# %%
plt.plot(numeric_dates, ss)
plt.plot(numeric_dates, sinusoidal_function(numeric_dates, 7, 365, 90, 0, 0.0001))

# %%
import numpy as np
import matplotlib.pyplot as plt
import ruptures as rpt

# Generate synthetic time series with a change point
np.random.seed(42)
data = np.concatenate([np.random.normal(0, 1, 50),
                       np.random.normal(5, 1, 50)])
data = ts.values
data = trend.values

# Perform change point detection using Pelt method
model = "l1"  # "l1" for absolute deviation, "rbf" for radial basis function
algo = rpt.Pelt(model=model, min_size=1, jump=1).fit(data)
result = algo.predict(pen=10)

# Plot the original time series and change point detection result
plt.figure(figsize=(12, 6))
plt.plot(data, label='Original Time Series', color='blue')
for r in result:
    plt.axvline(r, color='red', linestyle='--')
plt.title('Change Point Detection')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
peaks, _ = scipy.signal.find_peaks(trend.values, height=0)

# split time series between peaks
trend_split = np.split(trend, peaks)

# %%
for t in trend_split:
    plt.plot(t)
    print(mk.original_test(t.values))
# Out:
# Mann_Kendall_Test(trend='increasing', h=True, p=8.67976357454836e-10, z=6.131969718742824, Tau=1.0, s=190.0, var_s=950.0, slope=0.2724169406276227, intercept=166.03893339213624)
# Mann_Kendall_Test(trend='decreasing', h=True, p=0.0, z=-9.087775057867153, Tau=-0.9393939393939394, s=-930.0, var_s=10450.0, slope=-0.22651632274222247, intercept=171.95222994102522)
# Mann_Kendall_Test(trend='decreasing', h=True, p=3.019806626980426e-14, z=-7.597015044026804, Tau=-1.0, s=-406.0, var_s=2842.0, slope=-0.6053570845059364, intercept=162.15150652897452)

# %%
fig, (ax1, ax2) = plt.subplots(2, 1)
ax1.plot(trend.values)
ax2.plot(np.gradient(trend.values))
ax2.plot(np.gradient(np.gradient(trend.values)))
for peak in peaks:
    ax1.axvline(peak, color='r')
    ax2.axvline(peak, color='r')

# %%
plt.plot(np.gradient(trend.values))

# %%
mk.original_test(ts)
mk.hamed_rao_modification_test(ts)
mk.yue_wang_modification_test(ts)
mk.trend_free_pre_whitening_modification_test(ts)
mk.pre_whitening_modification_test(ts)
mk.seasonal_sens_slope(ts.values)
mk.sens_slope(ts.values)
mk.correlated_seasonal_test(ts.values)
mk.seasonal_test(ts.values)
# Out:
# Seasonal_Mann_Kendall_Test(trend='decreasing', h=True, p=8.146283647647579e-11, z=-6.497874419197018, Tau=-0.5527950310559007, s=-178.0, var_s=742.0000000000001, slope=-2.4020821895970705, intercept=175.2918721590181)

# %%
model.plot()

# %%
model.seasonal.plot(color='g', label='seasonal transect 0')
import pandas as pd
plt.ylim(min(model.seasonal), max(model.seasonal))

# Indian Monsoon
for yr in range(2013, 2023):
    if yr == 2013:
        plt.fill_between(pd.date_range(datetime.datetime(yr, 4, 1), datetime.datetime(yr, 9, 1), freq='M'), min(model.seasonal), max(model.seasonal), color='orange', alpha=0.2, label='Indian Monsoon')
    else:
        plt.fill_between(pd.date_range(datetime.datetime(yr, 4, 1), datetime.datetime(yr, 9, 1), freq='M'), min(model.seasonal), max(model.seasonal), color='orange', alpha=0.2)
plt.legend()

# %%
files = os.listdir(os.path.join(os.getcwd(), 'data', 'info_islands'))
for file in files:
    island = file.split('_')[1]
    try:
        IslandTime.retrieve_island_info(island, 'Maldives', verbose=False)
    except:
        print(island)
        raise Exception('Error retrieving island info')

# %%
geotransform = img.GetGeoTransform()

geotransform
# Out:
# (330660.0, 3.0, 0.0, 67584.0, 0.0, -3.0)

# %%
from mpetools import Segmentation
# %load_ext autoreload
# %autoreload 2
# %matplotlib qt

island = 'Vodamulaa'
country = 'Maldives'
island_info = IslandTime.retrieve_island_info(island, country, verbose=False)
path_data = os.path.join(os.getcwd(), 'data', 'coastsat_data', '{}_{}'.format(island, country), 'PSScene', '{}_{}_2017_psscene_analytic_udm2'.format(island, country), 'PSScene')

listdir = os.listdir(path_data)
listfile = [f for f in listdir if f.endswith('_AnalyticMS_clip.tif')]

fig, (ax1, ax2) = plt.subplots(1, 2)
camera = Camera(fig)

for i in range(len(listfile))[1:2]:
    print('file #', i)

    first_file = listfile[i]
    corresponding_xml_file = first_file.replace('_AnalyticMS_clip.tif', '_AnalyticMS_metadata_clip.xml')

    str_date = first_file.split('_')[0]
    year = str_date[:4]
    month = str_date[4:6]
    day = str_date[6:8]
    datetime.datetime(int(year), int(month), int(day))

    xmldoc = minidom.parse(os.path.join(path_data, corresponding_xml_file))
    nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

    # XML parser refers to bands by numbers 1-4
    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
        
    img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
    geotransform = img.GetGeoTransform()
    blue = img.GetRasterBand(1).ReadAsArray()
    green = img.GetRasterBand(2).ReadAsArray()
    red = img.GetRasterBand(3).ReadAsArray()
    nir = img.GetRasterBand(4).ReadAsArray()

    # Multiply by corresponding coefficients
    redc = red * coeffs[3]
    redc = np.where(redc == 0., np.nan, redc)
    nirc = nir * coeffs[4]
    nirc = np.where(nirc == 0., np.nan, nirc)
    greenc = green * coeffs[2]
    greenc = np.where(greenc == 0., np.nan, greenc)
    bluec = blue * coeffs[1]
    bluec = np.where(bluec == 0., np.nan, bluec)
    rgb = np.dstack((redc, greenc, bluec))

    ndvi = (nirc.astype(float) - redc.astype(float)) / (nirc + redc)
    ndwi = (greenc.astype(float) - nirc.astype(float)) / (greenc + nirc)

    labels = ['NIR', 'NDWI', 'NDVI']#, 'red', 'green', 'blue']

    # Stacked array
    stacked = np.dstack((nirc, ndwi, ndvi, redc, greenc, bluec))

    segmented_image, cmap = Segmentation.unsupervised_classification(stacked, 7, plot_classification=True)
    #segmented_image, cmap = None, None

    #classes_to_consider = input('Classes to consider: ').split(' ')
    #classes_to_consider = np.array(classes_to_consider).astype(int)
    
    idx_color = 0
    color = ['red', 'green', 'blue']
    
    for label, img_l in zip(labels, [nirc, ndwi, ndvi]):#, redc, greenc, bluec]):

        polygons_dict, X_peaks, X, histogram_distribution = Segmentation.segmentation(img_l, rgb, label, segmented_image, cmap, classes_to_consider=None, plot_results=True, animation=True)
        #Segmentation.associate_peaks_to_classification(img_l, segmented_image, label, X, histogram_distribution, X_peaks, cmap)

        continue
        # polygon
        polygons = polygons_dict['otsu']['polygons']

        # sort by area
        areas = [polygon.area for polygon in polygons]

        # largest polygon
        polygon = polygons[np.argmax(areas)]

        # test to see if polygon is the island
        # if not, take the second largest polygon
        #center_of_image = shapely.geometry.Point(img_l.shape[0]/2, img_l.shape[1]/2)
        #if not polygon.contains(center_of_image):
        #    polygon = polygons[np.argsort(areas)[-2]]

        # plot polygon
        if label == 'NIR':
            gpd.GeoSeries(polygon).plot(label=label, ax=ax1, color=color[idx_color])

        idx_color += 1

    ax1.text(0, 0, '{}-{}-{}'.format(day, month, year))  
    ax1.imshow(rgb, alpha=0.)
    ax1.axis('off')
    ax2.imshow(rgb)
    #plt.legend()
    camera.snap()
    #plt.show()
    
animation = camera.animate()
#animation.save('polygon_evolution.gif', writer='Pillow', fps=10)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# file # 1
# MovieWriter Pillow unavailable; using Pillow instead.
# MovieWriter Pillow unavailable; using Pillow instead.
# MovieWriter Pillow unavailable; using Pillow instead.

# %%
minima = scipy.signal.argrelextrema(histogram_distribution, np.less)[0]
otsu = threshold_multiotsu(img_l[~np.isnan(img_l)], classes=2)

# %%
otsu
# Out:
# array([-0.06441987])

# %%
#X_peaks, X, histogram_distribution
fig = plt.figure()
camera = Camera(fig)

plt.hist(img_l.flatten(), bins=100, density=True, color='k', alpha=0.5, label='histogram NDWI')
plt.legend(fontsize=15, loc='upper right')
camera.snap()

plt.hist(img_l.flatten(), bins=100, density=True, color='k', alpha=0.5)
plt.plot(X, histogram_distribution, linewidth=2., color='r', label='KDE')
plt.legend(fontsize=15, loc='upper right')
camera.snap()

plt.hist(img_l.flatten(), bins=100, density=True, color='k', alpha=0.5)
plt.plot(X, histogram_distribution, linewidth=2., color='r')
for idx_peak, peak in enumerate(X_peaks):
    if idx_peak == 0:
        plt.axvline(peak, color='b', linestyle='--', linewidth=2., label='peaks')
    else:
        plt.axvline(peak, color='b', linestyle='--', linewidth=2.)
plt.legend(fontsize=15, loc='upper right')
camera.snap()

plt.hist(img_l.flatten(), bins=100, density=True, color='k', alpha=0.5)
plt.plot(X, histogram_distribution, linewidth=2., color='r')
for idx_peak, peak in enumerate(X_peaks):
   plt.axvline(peak, color='b', linestyle='--', linewidth=2.)
for idx_min, min in enumerate(minima):
    if idx_min == 0:
        plt.axvline(X[min], color='g', linestyle='--', linewidth=2., label='minima')
    else:
        plt.axvline(X[min], color='g', linestyle='--', linewidth=2.)
plt.legend(fontsize=15, loc='upper right')
camera.snap()

plt.hist(img_l.flatten(), bins=100, density=True, color='k', alpha=0.5)
plt.plot(X, histogram_distribution, linewidth=2., color='r')
for idx_peak, peak in enumerate(X_peaks):
   plt.axvline(peak, color='b', linestyle='--', linewidth=2.)
for idx_min, min in enumerate(minima):
    plt.axvline(X[min], color='g', linestyle='--', linewidth=2.)
plt.axvline(otsu[0], color='orange', linestyle='--', linewidth=2., label='Otsu threshold')
plt.legend(fontsize=15, loc='upper right')

camera.snap()

camera.animate().save('histogram_evolution.gif', writer='Pillow', fps=0.5)
# Out:
# MovieWriter Pillow unavailable; using Pillow instead.

# %%
#fig, (ax1, ax2) = plt.subplots(1, 2)
plt.figure()
plt.imshow(rgb)
plt.axis('off')
plt.show()

# %%
img_no_nan = img_l[~np.isnan(img_l)]
hist = np.histogram(img_no_nan.flatten(), bins=250)#int(np.sqrt(len(img_no_nan.flatten()))))
hist_dist = scipy.stats.rv_histogram(hist)
smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma=5.)
histogram_distribution = smoothed_signal
plt.plot(X, histogram_distribution)
plt.plot(X,hist_dist.pdf(X) )

# %%
c = plt.imshow(segmented_image, cmap)
plt.colorbar(c)

# %%
#cbar = plt.imshow(segmented_image)
#plt.colorbar(cbar)
center = [290, 275]

labels = np.unique(segmented_image.flatten())

for label in labels:
    plt.figure()
    mask = np.where(segmented_image == label, 1, 0)
    dist = np.hypot(center[0] - mask, center[1] - mask)
    plt.imshow(dist)
    plt.show()

# %%
classes_to_consider = input('Classes to consider: ').split(' ')

# %%
np.array(classes_to_consider).astype(int)
# Out:
# array([1, 2])

# %%
import itertools
labels = np.unique(segmented_image.flatten())
combinations = list(itertools.combinations(labels, 2))
list_thresholds = [np.mean(comb) for comb in combinations]

# %%
for th in list_thresholds:
    plt.figure()
    plt.title('Threshold: {}'.format(th))
    contours = measure.find_contours(segmented_image, th)

    # sort contours by area
    areas = [contour.shape[0] for contour in contours]

    #contour = contours[np.argmax(areas)]
    for contour in contours:
        plt.plot(contour[:, 1], contour[:, 0], color='k')
    plt.show()

# %%
plt.imshow(segmented_image, cmap=cmap)

# %%
plt.figure()
plt.imshow(rgb)

# %%
plt.figure()
img_l = bluec.copy()
kernel = scipy.stats.gaussian_kde(img_l[~np.isnan(img_l)].flatten())
X = np.linspace(min(img_l[~np.isnan(img_l)].flatten()), max(img_l[~np.isnan(img_l)].flatten()), 1000)
plt.plot(X, kernel(X))
peaks, _ = scipy.signal.find_peaks(kernel(X))
for peak in peaks:
    plt.axvline(X[peak], color='red')
plt.show()

# %%
def fill_polygon_extent(contour, img, threshold=20):

    # Expand image array with nan values for extent contouring
    shape_img = img.shape
    expanded_array = np.full((shape_img[0]+2, shape_img[1]+2), np.nan)
    expanded_array[1:shape_img[0]+1, 1:shape_img[1]+1] = img

    # Create a mask with nan values
    nan_mask = np.isnan(expanded_array)

    # Find contours
    contours_extent = measure.find_contours(nan_mask, 0.5)

    # Create shapely objects
    pol_extent = shapely.geometry.Polygon(contours_extent[0]-1)
    l_extent = shapely.geometry.LineString(pol_extent.exterior.coords)
    cc = shapely.geometry.LineString(contour)

    pp1 = shapely.geometry.Point(cc.coords[0])
    pp2 = shapely.geometry.Point(cc.coords[-1])

    list_dist1 = [pp1.distance(shapely.geometry.Point(point_l_extent)) for point_l_extent in l_extent.coords]
    idx_min1 = np.argmin(list_dist1)
    point1_l_extent = l_extent.coords[int(idx_min1)]

    list_dist2 = [pp2.distance(shapely.geometry.Point(point_l_extent)) for point_l_extent in l_extent.coords]
    idx_min2 = np.argmin(list_dist2)
    point2_l_extent = l_extent.coords[int(idx_min2)]

    if min(list_dist1) < threshold and min(list_dist2) < threshold:
        #print('both points are close to extent')

        point1 = shapely.geometry.Point(point1_l_extent)
        point2 = shapely.geometry.Point(point2_l_extent)

        # Find the indices of the points on the line
        index1 = None
        index2 = None

        for i, coord in enumerate(l_extent.coords):

            if shapely.geometry.Point(coord).equals(point1):
                index1 = i
            elif shapely.geometry.Point(coord).equals(point2):
                index2 = i

        if index1 is not None and index2 is not None:
            # Extract the segment between the two points
            if index1 < index2:
                segment = shapely.geometry.LineString(l_extent.coords[index1:index2 + 1])
            else:
                segment = shapely.geometry.LineString(l_extent.coords[index2:index1 + 1])
    
        # Combine the contour and the segment
        possibles_poly = [shapely.geometry.Polygon(list(segment.coords) + list(cc.coords)),
                        shapely.geometry.Polygon(list(reversed(list(segment.coords))) + list(cc.coords)),
                        shapely.geometry.Polygon(list(segment.coords) + list(reversed(list(cc.coords)))),
                        shapely.geometry.Polygon(list(reversed(list(segment.coords))) + list(reversed(list(cc.coords))))]

        # Check which polygon is valid
        for poly in possibles_poly:
            if poly.is_valid:
                return np.array(poly.exterior.coords)
        
        print('no poly is valid')
        for poly in possibles_poly:
            #p = gpd.GeoSeries(poly)
            #p.plot()
            plt.figure()
            plt.plot(*segment.xy)
            plt.plot(*cc.xy)
            plt.show()

    else:
        #print('not close to extent, returning same contour')
        return contour

def combine_close_endpoints(line1, line2, distance_threshold=10):
    endpoints = [
        shapely.geometry.Point(line1.coords[0]),
        shapely.geometry.Point(line1.coords[-1]),
        shapely.geometry.Point(line2.coords[0]),
        shapely.geometry.Point(line2.coords[-1])
    ]

    distances = [endpoints[0].distance(endpoints[2]),
                 endpoints[0].distance(endpoints[3]),
                 endpoints[1].distance(endpoints[2]),
                 endpoints[1].distance(endpoints[3])]

    if min(distances) < distance_threshold:
        combined_lines = [
            shapely.geometry.LineString(list(line1.coords) + list(line2.coords)),
            shapely.geometry.LineString(list(line1.coords) + list(reversed(line2.coords))),
            shapely.geometry.LineString(list(line1.coords) + list(reversed(line2.coords))),
            shapely.geometry.LineString(list(reversed(line1.coords)) + list(reversed(line2.coords)))
        ]

        combined_line = combined_lines[np.argmin([line.length for line in combined_lines])]
        return combined_line
    else:
        return None

def combine_contours(contours, extent, img, plot_int=False):

    # Extent of the image [0, 588, 0, 528]
    left = shapely.geometry.LineString([(extent[0], extent[3]), (extent[0], extent[2])])
    right = shapely.geometry.LineString([(extent[1], extent[3]), (extent[1], extent[2])])
    top = shapely.geometry.LineString([(extent[0], extent[2]), (extent[1], extent[2])])
    bottom = shapely.geometry.LineString([(extent[0], extent[3]), (extent[1], extent[3])])

    # Corners
    top_left = shapely.geometry.Point(extent[0], extent[2])
    top_right = shapely.geometry.Point(extent[1], extent[2])
    bottom_left = shapely.geometry.Point(extent[0], extent[3])
    bottom_right = shapely.geometry.Point(extent[1], extent[3])

    # Close almost closed contours
    for c in range(len(contours)):
        ls = shapely.geometry.LineString(contours[c])
        p1 = shapely.geometry.Point(ls.coords[0])
        p2 = shapely.geometry.Point(ls.coords[-1])

        if p1.distance(p2) < 10:
            contours[c] = np.concatenate([contours[c], [contours[c][0]]], axis=0)
    
    contours_select = [np.flip(c) for c in contours if (len(c) > 100) and not (shapely.geometry.LineString(c).is_closed)]
    contours_closed = [np.flip(c) for c in contours if (len(c) > 100) and (shapely.geometry.LineString(c).is_closed)]

    if contours_select == []:
        return contours_closed

    if plot_int:
        plt.figure()
        plt.title('Contours before combining close endpoints')
        for i in range(len(contours_select)):
            plt.plot(contours_select[i][:, 1], contours_select[i][:, 0], label=i)
        plt.legend()
        plt.axis('equal')
        plt.show()
    
    to_exclude = []

    for i in range(len(contours_select)):
        if i not in to_exclude:
            # LineString of the contour
            line1 = shapely.geometry.LineString(contours_select[i])

            for j in range(len(contours_select)):
                if i != j and j not in to_exclude:
                    line2 = shapely.geometry.LineString(contours_select[j])

                    lines = combine_close_endpoints(line1, line2)
                    
                    if lines is not None:
                        print('contour {} is combined with contour {}'.format(i, j))
                        contours_select[i] = np.array(lines.coords)
                        contours_select[j] = np.array(lines.coords)
                        # update contours in to_exclude
                        for k in to_exclude:
                            contours_select[k] = np.array(lines.coords)
                        to_exclude.append(j)

    # Remove duplicates using np.array_equal
    unique_arrays = []
    for arr in contours_select:
        if not any(np.array_equal(arr, unique_arr) for unique_arr in unique_arrays):
            unique_arrays.append(arr)
    
    contours_select = unique_arrays
    
    if plot_int:
        plt.figure()
        plt.title('Contours after combining close endpoints')
        for i in range(len(contours_select)):
            plt.plot(contours_select[i][:, 1], contours_select[i][:, 0], label=i)
        plt.legend()
        plt.axis('equal')
        plt.show()

    # Check for contours that are close to the extent
    for con in range(len(contours_select)):
        #print(contours_select[con])
        contours_select[con] = fill_polygon_extent(contours_select[con], img)
        #print(contours_select[con])

        '''
        line1 = shapely.geometry.LineString(np.flip(contours_select[con]))
        point1 = shapely.geometry.Point(line1.coords[0])
        point2 = shapely.geometry.Point(line1.coords[-1])
        
        if plot_int:
            plt.figure()
            plt.plot(*line1.xy)
            plt.plot(point1.x, point1.y, 'o')
            plt.plot(point2.x, point2.y, 'o')
            plt.plot(*left.xy, label='left')
            plt.plot(*right.xy, label='right')
            plt.plot(*top.xy, label='top')
            plt.plot(*bottom.xy, label='bottom')
            plt.legend()
            plt.show()
        
        point_closest_1 = None
        point_closest_2 = None

        labels = ['left', 'right', 'top', 'bottom']

        for label, ext in zip(labels, [left, right, top, bottom]):
            if point1.distance(ext) < 50:
                point_closest_1 = label

            if point2.distance(ext) < 50:
                point_closest_2 = label
        
        if point_closest_1 is not None and point_closest_2 is not None:
            print('both close to extent')
            closest = [point_closest_1, point_closest_2]

            if point_closest_1 == point_closest_2:
                print('same extent')
                contours_select[con] = np.concatenate([contours_select[con], [contours_select[con][0]]], axis=0)
                
            elif closest == ['left', 'right'] or closest == ['right', 'left']:
                print('left and right')
                # Check if the line is closer to the top or bottom

                if point1.distance(top) < point1.distance(bottom):
                    # append contour with top-left and top-right
                    contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_right.coords)), np.flip(np.array(top_left.coords)), [contours_select[con][0]]],  axis=0)
                    if not shapely.geometry.Polygon(contours_select[con]).is_valid:
                        contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_left.coords)), np.flip(np.array(top_right.coords)), [contours_select[con][0]]], axis=0)
                            
                else:
                    # append contour with bottom-left and bottom-right
                    contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_right.coords)), np.flip(np.array(bottom_left.coords)), [contours_select[con][0]]],  axis=0)
                    if not shapely.geometry.Polygon(contours_select[con]).is_valid:
                        contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_left.coords)), np.flip(np.array(bottom_right.coords)), [contours_select[con][0]]], axis=0)
            
            elif closest == ['top', 'bottom'] or closest == ['bottom', 'top']:
                print('top and bottom')
                # Check if the line is closer to the left or right

                if point1.distance(left) < point1.distance(right):
                    # append contour with top-left and bottom-left
                    contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_left.coords)), np.flip(np.array(bottom_left.coords)), [contours_select[con][0]]],  axis=0)
                    if not shapely.geometry.Polygon(contours_select[con]).is_valid:
                        contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_left.coords)), np.flip(np.array(top_left.coords)), [contours_select[con][0]]], axis=0)
                else:
                    # append contour with top-right and bottom-right
                    contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_right.coords)),  np.flip(np.array(top_right.coords)), [contours_select[con][0]]],  axis=0)
                    if not shapely.geometry.Polygon(contours_select[con]).is_valid:
                        contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_right.coords)), np.flip(np.array(bottom_right.coords)), [contours_select[con][0]]], axis=0)
            
            elif closest == ['left', 'top'] or closest == ['top', 'left']:
                print('left and top')
                # append contour with top-left
                print(np.array(top_left.coords))
                contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_left.coords)), [contours_select[con][0]]],  axis=0)
            
            elif closest == ['left', 'bottom'] or closest == ['bottom', 'left']:
                print('left and bottom')
                # append contour with bottom-left
                contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_left.coords)), [contours_select[con][0]]],  axis=0)
            
            elif closest == ['right', 'top'] or closest == ['top', 'right']:
                print('right and top')
                # append contour with top-right
                contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(top_right.coords)), [contours_select[con][0]]],  axis=0)

            elif closest == ['right', 'bottom'] or closest == ['bottom', 'right']:
                print('right and bottom')
                # append contour with bottom-right
                contours_select[con] = np.concatenate([contours_select[con], np.flip(np.array(bottom_right.coords)), [contours_select[con][0]]],  axis=0)
            
            else:
                continue
            '''

    if plot_int:
        plt.figure()
        for con in contours_select:
            plt.plot(con[:, 1], con[:, 0])
        plt.axis('equal')
        plt.title('Contours after adding extent points')
        plt.show()

    # add closed contours
    for con in contours_closed:
        contours_select.append(con)

    return contours_select

# %%
def plot_polygons(polygons, label, ax):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 16

    polygonss = sorted(polygons, key=lambda poly: poly.area)
    for idx, pol in enumerate(polygonss):  
        if idx == 0:
            poll = pol
        else:
            poll = pol
            for i in reversed(range(idx)):
                poll = poll.difference(polygonss[i])

        p = gpd.GeoSeries(poll)
        p.plot(ax=ax, alpha=0.4, color=colors[idx])
    ax.set_title('polygons ' + label)
    ax.imshow(rgb)
    #plt.show()

listdir = os.listdir(path_data)
listfile = [f for f in listdir if f.endswith('_AnalyticMS_clip.tif')]

for i in range(len(listfile))[23:]:
    print('file #', i)

    first_file = listfile[i]
    corresponding_xml_file = first_file.replace('_AnalyticMS_clip.tif', '_AnalyticMS_metadata_clip.xml')

    str_date = first_file.split('_')[0]
    year = str_date[:4]
    month = str_date[4:6]
    day = str_date[6:8]
    datetime.datetime(int(year), int(month), int(day))

    xmldoc = minidom.parse(os.path.join(path_data, corresponding_xml_file))
    nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

    # XML parser refers to bands by numbers 1-4
    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
        
    img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
    blue = img.GetRasterBand(1).ReadAsArray()
    green = img.GetRasterBand(2).ReadAsArray()
    red = img.GetRasterBand(3).ReadAsArray()
    nir = img.GetRasterBand(4).ReadAsArray()

    # Multiply by corresponding coefficients
    redc = red * coeffs[3]
    nirc = nir * coeffs[4]
    greenc = green * coeffs[2]
    bluec = blue * coeffs[1]
    rgb = np.dstack((redc, greenc, bluec))

    ndvi = (nirc.astype(float) - redc.astype(float)) / (nirc + redc)
    ndwi = (greenc.astype(float) - nirc.astype(float)) / (greenc + nirc)

    labels = ['green', 'blue', 'NDWI', 'red', 'NIR', 'NDVI']
    for label, img_l in zip(labels, [greenc, bluec, ndwi, redc, nirc, ndvi]):

        print(label)
        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

        imgg = img_l.copy()
        imgg = np.where(imgg == 0., np.nan, imgg)

        # Get the dimensions of the image
        height, width = imgg.shape

        # Calculate the extent
        min_x = 0
        max_x = width - 1
        min_y = 0
        max_y = height - 1

        extent = [min_x, max_x, min_y, max_y]

        # First Otsu to remove water
        f_otsu = threshold_multiotsu(imgg[~np.isnan(imgg)], classes=2)

        # Distribution of ndwi
        ndwi_cut = imgg[~np.isnan(imgg)] #[imgg[~np.isnan(imgg)] > f_otsu[0]]

        hist = np.histogram(ndwi_cut, bins=150)
        X = np.linspace(min(ndwi_cut), max(ndwi_cut), 10000)
        #plt.hist(ndwi_cut, bins=250, density=True)
        hist_dist = scipy.stats.rv_histogram(hist)
        sigma = 50.  # Adjust the standard deviation as needed
        smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma)
        ax3.plot(X, hist_dist.pdf(X), label='histogram')
        ax3.plot(X, smoothed_signal, label='smoothed PDF')

        peaks, _ = scipy.signal.find_peaks(smoothed_signal, height=0.5)
        minima = scipy.signal.argrelextrema(smoothed_signal, np.less, order=50)[0]

        for idx_peak, peak in enumerate(peaks):
            if idx_peak == 0:
                ax3.axvline(X[peak], color='r', label='peaks')
            else:
                ax3.axvline(X[peak], color='r')
        for idx_mini, mini in enumerate(minima): 
            if idx_mini == 0:
                ax3.axvline(X[mini], color='g', label='minima')
            else:
                ax3.axvline(X[mini], color='g')
        ax3.axvline(f_otsu, color='orange')
        ax3.legend()
        ax3.set_title('pixel value histogram: ' + label)
        #plt.show()

        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1500
          # 2 row, 2 columns
        otsu = X[minima]
        polygons = []
        for idx_t, t in enumerate(list(reversed(otsu))):
            contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
            contours_select = [np.flip(c) for c in contours if len(c) > 100]
            contours_select = combine_contours(contours_select, extent, imgg)
            
            if len(contours_select) == 0:
                contours_combined = contours_select
            else:
                contours_combined = np.concatenate(contours_select)
            ax1.imshow(rgb)

            for c in contours_select:
                polygons.append(shapely.geometry.Polygon(np.flip(c)))

            for iii, cc in enumerate(contours_select):
                ax1.plot(cc[:, 1], cc[:, 0])
            
        ax1.set_title('RGB and contours {}-{}-{}'.format(year, month, day))
        ax2.imshow(img_l)
        ax2.set_title(label)
        ax4.set_title('polygons ' + label)
        ax4.imshow(rgb)

        plot_polygons(polygons, label=label, ax=ax4)

        plt.show()
# Out:
# file # 23
# green
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\mp222\OneDrive - Imperial College London\IslandTimeGitHub\IslandTime\timeseries_planet.ipynb Cell 14 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#Y104sZmlsZQ%3D%3D?line=119'>120</a> contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#Y104sZmlsZQ%3D%3D?line=120'>121</a> contours_select = [np.flip(c) for c in contours if len(c) > 100]
# ...

# %%
def plot_polygons(polygons, label, ax):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 16

    polygonss = sorted(polygons, key=lambda poly: poly.area)
    for idx, pol in enumerate(polygonss):  
        if idx == 0:
            poll = pol
        else:
            poll = pol
            for i in reversed(range(idx)):
                poll = poll.difference(polygonss[i])

        p = gpd.GeoSeries(poll)
        p.plot(ax=ax, alpha=0.4, color=colors[idx])
    ax.set_title('polygons ' + label)
    ax.imshow(rgb)
    #plt.show()

listdir = os.listdir(path_data)
listfile = [f for f in listdir if f.endswith('_AnalyticMS_clip.tif')]

for i in range(len(listfile))[:1]:

    first_file = listfile[i]
    corresponding_xml_file = first_file.replace('_AnalyticMS_clip.tif', '_AnalyticMS_metadata_clip.xml')

    str_date = first_file.split('_')[0]
    year = str_date[:4]
    month = str_date[4:6]
    day = str_date[6:8]
    datetime.datetime(int(year), int(month), int(day))

    xmldoc = minidom.parse(os.path.join(path_data, corresponding_xml_file))
    nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

    # XML parser refers to bands by numbers 1-4
    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
        
    img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
    blue = img.GetRasterBand(1).ReadAsArray()
    green = img.GetRasterBand(2).ReadAsArray()
    red = img.GetRasterBand(3).ReadAsArray()
    nir = img.GetRasterBand(4).ReadAsArray()

    # Multiply by corresponding coefficients
    redc = red * coeffs[3]
    nirc = nir * coeffs[4]
    greenc = green * coeffs[2]
    bluec = blue * coeffs[1]
    rgb = np.dstack((redc, greenc, bluec))

    ndvi = (nirc.astype(float) - redc.astype(float)) / (nirc + redc)
    ndwi = (greenc.astype(float) - nirc.astype(float)) / (greenc + nirc)

    labels = ['NDVI', 'red', 'NIR', 'green', 'blue', 'NDWI']
    for label, img_l in zip(labels, [ndvi, redc, nirc, greenc, bluec, ndwi]):

        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

        imgg = img_l.copy()
        imgg = np.where(imgg == 0., np.nan, imgg)

        # Get the dimensions of the image
        height, width = imgg.shape

        # Calculate the extent
        min_x = 0
        max_x = width - 1
        min_y = 0
        max_y = height - 1

        extent = [min_x, max_x, min_y, max_y]

        # First Otsu to remove water
        f_otsu = threshold_multiotsu(imgg[~np.isnan(imgg)], classes=2)

        # Distribution of ndwi
        ndwi_cut = imgg[~np.isnan(imgg)] #[imgg[~np.isnan(imgg)] > f_otsu[0]]

        hist = np.histogram(ndwi_cut, bins=150)
        X = np.linspace(min(ndwi_cut), max(ndwi_cut), 10000)
        #plt.hist(ndwi_cut, bins=250, density=True)
        hist_dist = scipy.stats.rv_histogram(hist)
        sigma = 50.  # Adjust the standard deviation as needed
        smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma)
        ax3.plot(X, hist_dist.pdf(X), label='histogram')
        ax3.plot(X, smoothed_signal, label='smoothed PDF')

        peaks, _ = scipy.signal.find_peaks(smoothed_signal, height=0.5)
        minima = scipy.signal.argrelextrema(smoothed_signal, np.less, order=50)[0]

        for idx_peak, peak in enumerate(peaks):
            if idx_peak == 0:
                ax3.axvline(X[peak], color='r', label='peaks')
            else:
                ax3.axvline(X[peak], color='r')
        for idx_mini, mini in enumerate(minima): 
            if idx_mini == 0:
                ax3.axvline(X[mini], color='g', label='minima')
            else:
                ax3.axvline(X[mini], color='g')
        ax3.axvline(f_otsu, color='orange')
        ax3.legend()
        ax3.set_title('pixel value histogram: ' + label)
        #plt.show()

        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1500
          # 2 row, 2 columns
        otsu = X[minima]
        print(list(reversed(otsu[:1])))
        polygons = []
        for idx_t, t in enumerate(list(reversed(otsu))):
            contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
            contours_select = [np.flip(c) for c in contours if len(c) > 50]
            contours_select = combine_contours(contours_select, extent)
            
            if len(contours_select) == 0:
                contours_combined = contours_select
            else:
                contours_combined = np.concatenate(contours_select)
            ax1.imshow(rgb)

            for c in contours_select:
                polygons.append(shapely.geometry.Polygon(np.flip(c)))

            for iii, cc in enumerate(contours_select):
                ax1.plot(cc[:, 1], cc[:, 0])
            
        ax1.set_title('RGB and contours {}-{}-{}'.format(year, month, day))
        ax2.imshow(img_l)
        ax2.set_title(label)

        plot_polygons(polygons, label=label, ax=ax4)

        plt.show()
        break
# Out:
# [-0.6099010185910392]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mp222\OneDrive - Imperial College London\IslandTimeGitHub\IslandTime\timeseries_planet.ipynb Cell 8 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#X61sZmlsZQ%3D%3D?line=118'>119</a> contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#X61sZmlsZQ%3D%3D?line=119'>120</a> contours_select = [np.flip(c) for c in contours if len(c) > 50]
# ...

# %%
def plot_polygons(polygons, label, ax):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 16

    polygonss = sorted(polygons, key=lambda poly: poly.area)
    for idx, pol in enumerate(polygonss):  
        if idx == 0:
            poll = pol
        else:
            poll = pol
            for i in reversed(range(idx)):
                poll = poll.difference(polygonss[i])

        p = gpd.GeoSeries(poll)
        p.plot(ax=ax, alpha=0.4, color=colors[idx])
    ax.set_title('polygons ' + label)
    ax.imshow(rgb)
    #plt.show()

listdir = os.listdir(path_data)
listfile = [f for f in listdir if f.endswith('_AnalyticMS_clip.tif')]

for i in range(len(listfile))[:1]:

    first_file = listfile[i]
    corresponding_xml_file = first_file.replace('_AnalyticMS_clip.tif', '_AnalyticMS_metadata_clip.xml')

    str_date = first_file.split('_')[0]
    year = str_date[:4]
    month = str_date[4:6]
    day = str_date[6:8]
    datetime.datetime(int(year), int(month), int(day))

    xmldoc = minidom.parse(os.path.join(path_data, corresponding_xml_file))
    nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

    # XML parser refers to bands by numbers 1-4
    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
        
    img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
    blue = img.GetRasterBand(1).ReadAsArray()
    green = img.GetRasterBand(2).ReadAsArray()
    red = img.GetRasterBand(3).ReadAsArray()
    nir = img.GetRasterBand(4).ReadAsArray()

    # Multiply by corresponding coefficients
    redc = red * coeffs[3]
    nirc = nir * coeffs[4]
    greenc = green * coeffs[2]
    bluec = blue * coeffs[1]
    rgb = np.dstack((redc, greenc, bluec))

    ndvi = (nirc.astype(float) - redc.astype(float)) / (nirc + redc)
    ndwi = (greenc.astype(float) - nirc.astype(float)) / (greenc + nirc)

    labels = ['NDVI', 'red', 'NIR', 'green', 'blue', 'NDWI']
    for label, img_l in zip(labels, [ndvi, redc, nirc, greenc, bluec, ndwi]):

        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

        imgg = img_l.copy()
        imgg = np.where(imgg == 0., np.nan, imgg)

        # Get the dimensions of the image
        height, width = imgg.shape

        # Calculate the extent
        min_x = 0
        max_x = width - 1
        min_y = 0
        max_y = height - 1

        extent = [min_x, max_x, min_y, max_y]

        # First Otsu to remove water
        f_otsu = threshold_multiotsu(imgg[~np.isnan(imgg)], classes=2)

        # Distribution of ndwi
        ndwi_cut = imgg[~np.isnan(imgg)] #[imgg[~np.isnan(imgg)] > f_otsu[0]]

        hist = np.histogram(ndwi_cut, bins=150)
        X = np.linspace(min(ndwi_cut), max(ndwi_cut), 10000)
        #plt.hist(ndwi_cut, bins=250, density=True)
        hist_dist = scipy.stats.rv_histogram(hist)
        sigma = 50.  # Adjust the standard deviation as needed
        smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma)
        ax3.plot(X, hist_dist.pdf(X), label='histogram')
        ax3.plot(X, smoothed_signal, label='smoothed PDF')

        peaks, _ = scipy.signal.find_peaks(smoothed_signal, height=0.5)
        minima = scipy.signal.argrelextrema(smoothed_signal, np.less, order=50)[0]

        for idx_peak, peak in enumerate(peaks):
            if idx_peak == 0:
                ax3.axvline(X[peak], color='r', label='peaks')
            else:
                ax3.axvline(X[peak], color='r')
        for idx_mini, mini in enumerate(minima): 
            if idx_mini == 0:
                ax3.axvline(X[mini], color='g', label='minima')
            else:
                ax3.axvline(X[mini], color='g')
        ax3.axvline(f_otsu, color='orange')
        ax3.legend()
        ax3.set_title('pixel value histogram: ' + label)
        #plt.show()

        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1500
          # 2 row, 2 columns
        otsu = X[minima]
        print(list(reversed(otsu[:1])))
        polygons = []
        for idx_t, t in enumerate(list(reversed(otsu))):
            contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
            contours_select = [np.flip(c) for c in contours if len(c) > 50]
            contours_select = combine_contours(contours_select, extent)
            
            if len(contours_select) == 0:
                contours_combined = contours_select
            else:
                contours_combined = np.concatenate(contours_select)
            ax1.imshow(rgb)

            for c in contours_select:
                polygons.append(shapely.geometry.Polygon(np.flip(c)))

            for iii, cc in enumerate(contours_select):
                ax1.plot(cc[:, 1], cc[:, 0])
            
        ax1.set_title('RGB and contours {}-{}-{}'.format(year, month, day))
        ax2.imshow(img_l)
        ax2.set_title(label)

        plot_polygons(polygons, label=label, ax=ax4)

        plt.show()
        break
# Out:
# [-0.6099010185910392]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mp222\OneDrive - Imperial College London\IslandTimeGitHub\IslandTime\timeseries_planet.ipynb Cell 12 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#X45sZmlsZQ%3D%3D?line=118'>119</a> contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#X45sZmlsZQ%3D%3D?line=119'>120</a> contours_select = [np.flip(c) for c in contours if len(c) > 50]
# ...

# %%
def plot_polygons(polygons, label, ax):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 16

    polygonss = sorted(polygons, key=lambda poly: poly.area)
    for idx, pol in enumerate(polygonss):  
        if idx == 0:
            poll = pol
        else:
            poll = pol
            for i in reversed(range(idx)):
                poll = poll.difference(polygonss[i])

        p = gpd.GeoSeries(poll)
        p.plot(ax=ax, alpha=0.4, color=colors[idx])
    ax.set_title('polygons ' + label)
    ax.imshow(rgb)
    #plt.show()

listdir = os.listdir(path_data)
listfile = [f for f in listdir if f.endswith('_AnalyticMS_clip.tif')]

for i in range(len(listfile))[:1]:

    first_file = listfile[i]
    corresponding_xml_file = first_file.replace('_AnalyticMS_clip.tif', '_AnalyticMS_metadata_clip.xml')

    str_date = first_file.split('_')[0]
    year = str_date[:4]
    month = str_date[4:6]
    day = str_date[6:8]
    datetime.datetime(int(year), int(month), int(day))

    xmldoc = minidom.parse(os.path.join(path_data, corresponding_xml_file))
    nodes = xmldoc.getElementsByTagName("ps:bandSpecificMetadata")

    # XML parser refers to bands by numbers 1-4
    coeffs = {}
    for node in nodes:
        bn = node.getElementsByTagName("ps:bandNumber")[0].firstChild.data
        if bn in ['1', '2', '3', '4']:
            i = int(bn)
            value = node.getElementsByTagName("ps:reflectanceCoefficient")[0].firstChild.data
            coeffs[i] = float(value)
        
    img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
    blue = img.GetRasterBand(1).ReadAsArray()
    green = img.GetRasterBand(2).ReadAsArray()
    red = img.GetRasterBand(3).ReadAsArray()
    nir = img.GetRasterBand(4).ReadAsArray()

    # Multiply by corresponding coefficients
    redc = red * coeffs[3]
    nirc = nir * coeffs[4]
    greenc = green * coeffs[2]
    bluec = blue * coeffs[1]
    rgb = np.dstack((redc, greenc, bluec))

    ndvi = (nirc.astype(float) - redc.astype(float)) / (nirc + redc)
    ndwi = (greenc.astype(float) - nirc.astype(float)) / (greenc + nirc)

    labels = ['NDVI', 'red', 'NIR', 'green', 'blue', 'NDWI']
    for label, img_l in zip(labels, [ndvi, redc, nirc, greenc, bluec, ndwi]):

        fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2)

        imgg = img_l.copy()
        imgg = np.where(imgg == 0., np.nan, imgg)

        # Get the dimensions of the image
        height, width = imgg.shape

        # Calculate the extent
        min_x = 0
        max_x = width - 1
        min_y = 0
        max_y = height - 1

        extent = [min_x, max_x, min_y, max_y]

        # First Otsu to remove water
        f_otsu = threshold_multiotsu(imgg[~np.isnan(imgg)], classes=2)

        # Distribution of ndwi
        ndwi_cut = imgg[~np.isnan(imgg)] #[imgg[~np.isnan(imgg)] > f_otsu[0]]

        hist = np.histogram(ndwi_cut, bins=150)
        X = np.linspace(min(ndwi_cut), max(ndwi_cut), 10000)
        #plt.hist(ndwi_cut, bins=250, density=True)
        hist_dist = scipy.stats.rv_histogram(hist)
        sigma = 50.  # Adjust the standard deviation as needed
        smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma)
        ax3.plot(X, hist_dist.pdf(X), label='histogram')
        ax3.plot(X, smoothed_signal, label='smoothed PDF')

        peaks, _ = scipy.signal.find_peaks(smoothed_signal, height=0.5)
        minima = scipy.signal.argrelextrema(smoothed_signal, np.less, order=50)[0]

        for idx_peak, peak in enumerate(peaks):
            if idx_peak == 0:
                ax3.axvline(X[peak], color='r', label='peaks')
            else:
                ax3.axvline(X[peak], color='r')
        for idx_mini, mini in enumerate(minima): 
            if idx_mini == 0:
                ax3.axvline(X[mini], color='g', label='minima')
            else:
                ax3.axvline(X[mini], color='g')
        ax3.axvline(f_otsu, color='orange')
        ax3.legend()
        ax3.set_title('pixel value histogram: ' + label)
        #plt.show()

        colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1500
          # 2 row, 2 columns
        otsu = X[minima]
        print(list(reversed(otsu[:1])))
        polygons = []
        for idx_t, t in enumerate(list(reversed(otsu))):
            contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
            contours_select = [np.flip(c) for c in contours if len(c) > 50]
            contours_select = combine_contours(contours_select, extent)
            
            if len(contours_select) == 0:
                contours_combined = contours_select
            else:
                contours_combined = np.concatenate(contours_select)
            ax1.imshow(rgb)

            for c in contours_select:
                polygons.append(shapely.geometry.Polygon(np.flip(c)))

            for iii, cc in enumerate(contours_select):
                ax1.plot(cc[:, 1], cc[:, 0])
            
        ax1.set_title('RGB and contours {}-{}-{}'.format(year, month, day))
        ax2.imshow(img_l)
        ax2.set_title(label)

        plot_polygons(polygons, label=label, ax=ax4)

        plt.show()
        break
# Out:
# [-0.6099010185910392]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\mp222\OneDrive - Imperial College London\IslandTimeGitHub\IslandTime\timeseries_planet.ipynb Cell 13 line 1
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#W4sZmlsZQ%3D%3D?line=118'>119</a> contours = measure.find_contours(imgg, t, fully_connected='high', positive_orientation='high')
#     <a href='vscode-notebook-cell:/c%3A/Users/mp222/OneDrive%20-%20Imperial%20College%20London/IslandTimeGitHub/IslandTime/timeseries_planet.ipynb#W4sZmlsZQ%3D%3D?line=119'>120</a> contours_select = [np.flip(c) for c in contours if len(c) > 50]
# ...

# %%
from PIL import Image
im = Image.open('Dry_tif_tests.tif')
arr = np.array(im)

def plot_polygons(polygons):
    colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1000

    polygonss = sorted(polygons, key=lambda poly: poly.area)
    fig, ax = plt.subplots()
    for idx, pol in enumerate(polygonss):  
        
        if idx == 0:
            poll = pol
        else:
            poll = pol
            for i in reversed(range(idx)):
                poll = poll.difference(polygonss[i])

        p = gpd.GeoSeries(poll)
        p.plot(ax=ax, alpha=0.4, color=colors[idx])
    plt.imshow(arr)
    plt.show()

plt.figure()
hist = np.histogram(arr.flatten(), bins=500)
X = np.linspace(min(arr.flatten()), max(arr.flatten()), 10000)
#plt.hist(ndwi_cut, bins=250, density=True)
hist_dist = scipy.stats.rv_histogram(hist)
sigma = 100.  # Adjust the standard deviation as needed
smoothed_signal = scipy.ndimage.gaussian_filter(hist_dist.pdf(X), sigma)
plt.plot(X, hist_dist.pdf(X))
plt.plot(X, smoothed_signal)

peaks, _ = scipy.signal.find_peaks(smoothed_signal, height=0.5)
minima = scipy.signal.argrelextrema(smoothed_signal, np.less, order=50)[0]

for peak in peaks: plt.axvline(X[peak], color='r')
for mini in minima: plt.axvline(X[mini], color='g')
plt.show()

colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] * 1000
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))  # 1 row, 2 columns
otsu = X[minima]
print(list(reversed(otsu)))
polygons = []
for idx_t, t in enumerate(list(reversed(otsu))):
    contours = measure.find_contours(arr, t, fully_connected='high', positive_orientation='high')
    contours_select = [c for c in contours if len(c) > 0]
    #contours_select = combine_contours(contours_select, extent)
    
    if len(contours_select) == 0:
        contours_combined = contours_select
    else:
        contours_combined = np.concatenate(contours_select)
    ax1.imshow(arr)

    for c in contours_select:
        polygons.append(shapely.geometry.Polygon(c))

    for iii, cc in enumerate(contours_select):
        ax1.plot(cc[:, 1], cc[:, 0], color='k', linewidth=0.5)
    
#ax1.set_title('{}-{}-{}'.format(year, month, day))
ax2.imshow(arr)
#ax2.set_title('RGB')
#ax1.legend()
plt.show()

#plot_polygons(polygons)
# Out:
# [245.74457445744574, 220.43154315431542, 206.47034703470345, 131.06650665066508, 98.54985498549854]

# %%
img = gdal.Open(os.path.join(path_data, first_file), gdal.GA_ReadOnly)
blue = img.GetRasterBand(1).ReadAsArray()
green = img.GetRasterBand(2).ReadAsArray()
red = img.GetRasterBand(3).ReadAsArray()
nir = img.GetRasterBand(4).ReadAsArray()

# Get geospatial information
geotransform = img.GetGeoTransform()
projection = img.GetProjection()

# Extract geospatial parameters
x_origin = geotransform[0]
y_origin = geotransform[3]
pixel_width = geotransform[1]
pixel_height = geotransform[5]

# Create arrays of longitude and latitude coordinates
width, height = img.RasterXSize, img.RasterYSize
x_coords = np.arange(width) * pixel_width + x_origin
y_coords = np.arange(height) * pixel_height + y_origin

# Create a meshgrid of longitude and latitude
lon, lat = np.meshgrid(x_coords, y_coords)

src_crs = pyproj.CRS('EPSG:{}'.format(pyproj.CRS.from_string(projection).to_epsg()))
tgt_crs = pyproj.CRS('EPSG:4326')

# Create a transformer
transformer = pyproj.Transformer.from_crs(src_crs, tgt_crs, always_xy=True)

# Reproject the data
x_reprojected, y_reprojected = transformer.transform(lon, lat)

# Create a figure and plot the GeoTIFF data
plt.figure(figsize=(10, 10))
plt.imshow(nir, extent=[x_reprojected.min(), x_reprojected.max(), y_reprojected.min(), y_reprojected.max()], cmap='viridis')
plt.scatter(island_info['spatial_reference']['longitude'], island_info['spatial_reference']['latitude'])

# You can add more customization to the plot, such as labels, a colorbar, etc.
plt.title("GeoTIFF Image with Lat-Lon Coordinates")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.colorbar(label="Data Values")

# Show the plot
plt.show()

# %%
from segment_anything import SamPredictor, sam_model_registry, SamAutomaticMaskGenerator
from PIL import Image
import cv2
im = cv2.imread('Dry_tif_tests.tif')
im = cv2.imread('Cat_August_2010-4.jpg')
sam = sam_model_registry["vit_h"](checkpoint="sam_vit_h_4b8939.pth")
mask_generator = SamAutomaticMaskGenerator(sam)
masks = mask_generator.generate(im)

# %%
def show_anns(anns, axes=None):
    if len(anns) == 0:
        return
    if axes:
        ax = axes
    else:
        ax = plt.gca()
        ax.set_autoscale_on(False)
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    polygons = []
    color = []
    for ann in sorted_anns:
        m = ann['segmentation']
        img = np.ones((m.shape[0], m.shape[1], 3))
        color_mask = np.random.random((1, 3)).tolist()[0]
        for i in range(3):
            img[:,:,i] = color_mask[i]
        ax.imshow(np.dstack((img, m**0.5)))

# %%
# Plot the original image and the mask
fig, axs = plt.subplots(1, 2, figsize=(16, 16))
axs[0].imshow(img_l)
axs[1].imshow(img_l)
show_anns(masks, axs[1])
axs[0].axis('off')
axs[1].axis('off')
plt.show()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
import cv2
from sklearn.impute import SimpleImputer


image = np.stack([redc, bluec, greenc, ndwi, ndvi, nirc], axis=2)

imputer = SimpleImputer(strategy='mean')

for i in range(image.shape[2]):
    image[:, :, i] = imputer.fit_transform(image[:, :, i])

# Reshape the image to a 2D array of pixels (rows) by RGB values (columns)
image_shape = image.shape
image_2d = image.reshape((-1, image_shape[2]))

# Number of clusters (adjust this based on your needs)
n_clusters = 7

# Fit the k-means model to the image data
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
kmeans.fit(image_2d)

# Get the labels assigned to each pixel
labels = kmeans.labels_

# Reshape the labels back to the shape of the original image
segmented_image = labels.reshape(image_shape[0], image_shape[1])

# %%
from matplotlib.colors import ListedColormap

cmap = ListedColormap(['blue', 'orange', 'green', 'purple', 'yellow', 'red', 'pink'])

# Display the original and segmented images
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.title('Original Image')
plt.imshow(rgb)
cont = measure.find_contours(segmented_image, 0.5)
#for c in cont:
 #   plt.plot(c[:, 1], c[:, 0])
plt.axis('off')

plt.subplot(1, 2, 2)
plt.title('Segmented Image')
cbar = plt.imshow(segmented_image, cmap=cmap)  # You can choose a different colormap]
plt.colorbar(cbar)
#for c in cont:
    #plt.plot(c[:, 1], c[:, 0], color='k')
plt.axis('off')

plt.show()

# %%
arr = nir
plt.figure()
plt.hist(arr.flatten(), bins=1000, label='NDWI', alpha=0.2, color='k')
for label in np.unique(labels):
    mask = np.where(segmented_image == label, 1, 0)
    masked_nir = np.where(mask == 1, arr, np.nan)
    plt.hist(masked_nir.flatten(), bins=1000, label=label, alpha=0.5, color=cmap.colors[label])

plt.legend()
plt.show()

# %%
threshold_multiotsu(nirc[~np.isnan(nirc)], classes=2)

# %%
plt.figure()
plt.imshow(np.where(segmented_image == 6, 1, 0))

# %%
cont = measure.find_contours(nirc)
plt.imshow(segmented_image)
for c in cont:
    plt.plot(c[:, 1], c[:, 0])
